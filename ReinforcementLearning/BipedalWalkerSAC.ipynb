# %%
import gym
from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %%
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env

# %%
from gym.envs import box2d

# %%
environment_name = "BipedalWalker-v3"

# %%
env = gym.make(environment_name, hardcore=True)

# %%
env.action_space.sample()
# Out:
# array([-0.0092526 ,  0.6516297 , -0.28077862, -0.7503878 ], dtype=float32)

# %%
vec_env = make_vec_env(environment_name, n_envs=4)

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = SAC("MlpPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\im5431590\AppData\Local\miniconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
model.learn(total_timesteps=1000000)
# Out:
# Logging to Training\Logs\SAC_2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 529      |
# |    ep_rew_mean     | -107     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 45       |
# |    time_elapsed    | 47       |
# |    total_timesteps | 2117     |
# | train/             |          |
# |    actor_loss      | -17.5    |
# |    critic_loss     | 0.527    |
# |    ent_coef        | 0.547    |
# |    ent_coef_loss   | -4.02    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2016     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 498      |
# |    ep_rew_mean     | -106     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 43       |
# |    time_elapsed    | 91       |
# |    total_timesteps | 3982     |
# | train/             |          |
# |    actor_loss      | -23.4    |
# |    critic_loss     | 1.79     |
# |    ent_coef        | 0.317    |
# |    ent_coef_loss   | -6.97    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3881     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 355      |
# |    ep_rew_mean     | -107     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 43       |
# |    time_elapsed    | 98       |
# |    total_timesteps | 4255     |
# | train/             |          |
# |    actor_loss      | -23.5    |
# |    critic_loss     | 8.4      |
# |    ent_coef        | 0.294    |
# |    ent_coef_loss   | -7.18    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4154     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 283      |
# |    ep_rew_mean     | -110     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 42       |
# |    time_elapsed    | 106      |
# |    total_timesteps | 4521     |
# | train/             |          |
# |    actor_loss      | -22.2    |
# |    critic_loss     | 2.87     |
# |    ent_coef        | 0.272    |
# |    ent_coef_loss   | -7.45    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4420     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 260      |
# |    ep_rew_mean     | -115     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 42       |
# |    time_elapsed    | 123      |
# |    total_timesteps | 5197     |
# | train/             |          |
# |    actor_loss      | -22.7    |
# |    critic_loss     | 3.29     |
# |    ent_coef        | 0.226    |
# |    ent_coef_loss   | -8.15    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5096     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 286      |
# |    ep_rew_mean     | -120     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 41       |
# |    time_elapsed    | 163      |
# |    total_timesteps | 6862     |
# | train/             |          |
# |    actor_loss      | -21.2    |
# |    critic_loss     | 4.75     |
# |    ent_coef        | 0.146    |
# |    ent_coef_loss   | -6.61    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6761     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 272      |
# |    ep_rew_mean     | -122     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 41       |
# |    time_elapsed    | 182      |
# |    total_timesteps | 7604     |
# | train/             |          |
# |    actor_loss      | -20.1    |
# |    critic_loss     | 4.4      |
# |    ent_coef        | 0.123    |
# |    ent_coef_loss   | -6.32    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7503     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 250      |
# |    ep_rew_mean     | -121     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 41       |
# |    time_elapsed    | 192      |
# |    total_timesteps | 8010     |
# | train/             |          |
# |    actor_loss      | -22.9    |
# |    critic_loss     | 4.38     |
# |    ent_coef        | 0.112    |
# |    ent_coef_loss   | -6.44    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7909     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 246      |
# |    ep_rew_mean     | -120     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 41       |
# |    time_elapsed    | 213      |
# |    total_timesteps | 8867     |
# | train/             |          |
# |    actor_loss      | -18.5    |
# |    critic_loss     | 4.28     |
# |    ent_coef        | 0.0939   |
# |    ent_coef_loss   | -3.41    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8766     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 283      |
# |    ep_rew_mean     | -119     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 41       |
# |    time_elapsed    | 273      |
# |    total_timesteps | 11329    |
# | train/             |          |
# |    actor_loss      | -18.4    |
# |    critic_loss     | 4.86     |
# |    ent_coef        | 0.0522   |
# |    ent_coef_loss   | -4.29    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11228    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 264      |
# |    ep_rew_mean     | -118     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 41       |
# |    time_elapsed    | 279      |
# |    total_timesteps | 11600    |
# | train/             |          |
# |    actor_loss      | -16.9    |
# |    critic_loss     | 4.59     |
# |    ent_coef        | 0.0491   |
# |    ent_coef_loss   | -4.02    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 248      |
# |    ep_rew_mean     | -117     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 41       |
# |    time_elapsed    | 288      |
# |    total_timesteps | 11923    |
# | train/             |          |
# |    actor_loss      | -18.5    |
# |    critic_loss     | 4.83     |
# |    ent_coef        | 0.0461   |
# |    ent_coef_loss   | -2.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11822    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 234      |
# |    ep_rew_mean     | -116     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 41       |
# |    time_elapsed    | 295      |
# |    total_timesteps | 12194    |
# | train/             |          |
# |    actor_loss      | -15      |
# |    critic_loss     | 3.69     |
# |    ent_coef        | 0.0437   |
# |    ent_coef_loss   | -4.17    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12093    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 222      |
# |    ep_rew_mean     | -115     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 41       |
# |    time_elapsed    | 302      |
# |    total_timesteps | 12430    |
# | train/             |          |
# |    actor_loss      | -18      |
# |    critic_loss     | 4.35     |
# |    ent_coef        | 0.0417   |
# |    ent_coef_loss   | -2.98    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12329    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 264      |
# |    ep_rew_mean     | -115     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 39       |
# |    time_elapsed    | 398      |
# |    total_timesteps | 15860    |
# | train/             |          |
# |    actor_loss      | -12.7    |
# |    critic_loss     | 2.74     |
# |    ent_coef        | 0.0301   |
# |    ent_coef_loss   | -0.609   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15759    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 253      |
# |    ep_rew_mean     | -114     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 39       |
# |    time_elapsed    | 406      |
# |    total_timesteps | 16184    |
# | train/             |          |
# |    actor_loss      | -11      |
# |    critic_loss     | 5.67     |
# |    ent_coef        | 0.031    |
# |    ent_coef_loss   | 0.366    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16083    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 247      |
# |    ep_rew_mean     | -115     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 39       |
# |    time_elapsed    | 424      |
# |    total_timesteps | 16817    |
# | train/             |          |
# |    actor_loss      | -13      |
# |    critic_loss     | 4.14     |
# |    ent_coef        | 0.0324   |
# |    ent_coef_loss   | 1.22     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16716    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 301      |
# |    ep_rew_mean     | -114     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 38       |
# |    time_elapsed    | 557      |
# |    total_timesteps | 21682    |
# | train/             |          |
# |    actor_loss      | -16.9    |
# |    critic_loss     | 3.64     |
# |    ent_coef        | 0.0328   |
# |    ent_coef_loss   | 0.555    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21581    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 370      |
# |    ep_rew_mean     | -113     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 38       |
# |    time_elapsed    | 725      |
# |    total_timesteps | 28082    |
# | train/             |          |
# |    actor_loss      | -21.7    |
# |    critic_loss     | 2.7      |
# |    ent_coef        | 0.0384   |
# |    ent_coef_loss   | 1.99     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27981    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 431      |
# |    ep_rew_mean     | -113     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 38       |
# |    time_elapsed    | 894      |
# |    total_timesteps | 34482    |
# | train/             |          |
# |    actor_loss      | -18.3    |
# |    critic_loss     | 1.89     |
# |    ent_coef        | 0.0276   |
# |    ent_coef_loss   | -0.369   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 34381    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 439      |
# |    ep_rew_mean     | -113     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 38       |
# |    time_elapsed    | 954      |
# |    total_timesteps | 36903    |
# | train/             |          |
# |    actor_loss      | -16.3    |
# |    critic_loss     | 1.92     |
# |    ent_coef        | 0.0253   |
# |    ent_coef_loss   | -0.057   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 36802    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 448      |
# |    ep_rew_mean     | -113     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 38       |
# |    time_elapsed    | 1018     |
# |    total_timesteps | 39438    |
# | train/             |          |
# |    actor_loss      | -12.6    |
# |    critic_loss     | 1.96     |
# |    ent_coef        | 0.0239   |
# |    ent_coef_loss   | 1.71     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39337    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 462      |
# |    ep_rew_mean     | -112     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 38       |
# |    time_elapsed    | 1094     |
# |    total_timesteps | 42472    |
# | train/             |          |
# |    actor_loss      | -10.8    |
# |    critic_loss     | 1.94     |
# |    ent_coef        | 0.025    |
# |    ent_coef_loss   | 0.255    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 42371    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 451      |
# |    ep_rew_mean     | -112     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 38       |
# |    time_elapsed    | 1113     |
# |    total_timesteps | 43264    |
# | train/             |          |
# |    actor_loss      | -12.5    |
# |    critic_loss     | 1.34     |
# |    ent_coef        | 0.0258   |
# |    ent_coef_loss   | -0.269   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43163    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 497      |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 39       |
# |    time_elapsed    | 1266     |
# |    total_timesteps | 49664    |
# | train/             |          |
# |    actor_loss      | -11.6    |
# |    critic_loss     | 1.44     |
# |    ent_coef        | 0.0208   |
# |    ent_coef_loss   | 0.38     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49563    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 525      |
# |    ep_rew_mean     | -110     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 39       |
# |    time_elapsed    | 1387     |
# |    total_timesteps | 54624    |
# | train/             |          |
# |    actor_loss      | -6.33    |
# |    critic_loss     | 0.989    |
# |    ent_coef        | 0.0148   |
# |    ent_coef_loss   | -2.02    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 54523    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 514      |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 39       |
# |    time_elapsed    | 1404     |
# |    total_timesteps | 55361    |
# | train/             |          |
# |    actor_loss      | -7.41    |
# |    critic_loss     | 0.891    |
# |    ent_coef        | 0.014    |
# |    ent_coef_loss   | 0.12     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 55260    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 545      |
# |    ep_rew_mean     | -112     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 39       |
# |    time_elapsed    | 1486     |
# |    total_timesteps | 58721    |
# | train/             |          |
# |    actor_loss      | -4.73    |
# |    critic_loss     | 2.4      |
# |    ent_coef        | 0.0118   |
# |    ent_coef_loss   | -0.0908  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 58620    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 606      |
# |    ep_rew_mean     | -110     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 39       |
# |    time_elapsed    | 1646     |
# |    total_timesteps | 65121    |
# | train/             |          |
# |    actor_loss      | -3.47    |
# |    critic_loss     | 1.11     |
# |    ent_coef        | 0.012    |
# |    ent_coef_loss   | -0.431   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 65020    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 649      |
# |    ep_rew_mean     | -108     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 39       |
# |    time_elapsed    | 1773     |
# |    total_timesteps | 70106    |
# | train/             |          |
# |    actor_loss      | -3.53    |
# |    critic_loss     | 0.77     |
# |    ent_coef        | 0.0123   |
# |    ent_coef_loss   | -1.12    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 70005    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 666      |
# |    ep_rew_mean     | -106     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 39       |
# |    time_elapsed    | 1861     |
# |    total_timesteps | 73506    |
# | train/             |          |
# |    actor_loss      | -2.03    |
# |    critic_loss     | 0.718    |
# |    ent_coef        | 0.0108   |
# |    ent_coef_loss   | 0.585    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 73405    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 686      |
# |    ep_rew_mean     | -106     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 39       |
# |    time_elapsed    | 1925     |
# |    total_timesteps | 76175    |
# | train/             |          |
# |    actor_loss      | -1.29    |
# |    critic_loss     | 0.543    |
# |    ent_coef        | 0.00953  |
# |    ent_coef_loss   | -1.36    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 76074    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 720      |
# |    ep_rew_mean     | -106     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 39       |
# |    time_elapsed    | 2027     |
# |    total_timesteps | 79991    |
# | train/             |          |
# |    actor_loss      | -0.885   |
# |    critic_loss     | 0.423    |
# |    ent_coef        | 0.0111   |
# |    ent_coef_loss   | 0.311    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 79890    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 775      |
# |    ep_rew_mean     | -104     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 39       |
# |    time_elapsed    | 2213     |
# |    total_timesteps | 86391    |
# | train/             |          |
# |    actor_loss      | -0.0348  |
# |    critic_loss     | 0.963    |
# |    ent_coef        | 0.00939  |
# |    ent_coef_loss   | 0.438    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 86290    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 770      |
# |    ep_rew_mean     | -105     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 39       |
# |    time_elapsed    | 2259     |
# |    total_timesteps | 88356    |
# | train/             |          |
# |    actor_loss      | 1.7      |
# |    critic_loss     | 0.644    |
# |    ent_coef        | 0.00822  |
# |    ent_coef_loss   | 0.283    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 88255    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 814      |
# |    ep_rew_mean     | -105     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 39       |
# |    time_elapsed    | 2371     |
# |    total_timesteps | 92978    |
# | train/             |          |
# |    actor_loss      | 0.713    |
# |    critic_loss     | 0.493    |
# |    ent_coef        | 0.00774  |
# |    ent_coef_loss   | -0.829   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 92877    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 871      |
# |    ep_rew_mean     | -105     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 39       |
# |    time_elapsed    | 2521     |
# |    total_timesteps | 99011    |
# | train/             |          |
# |    actor_loss      | 3.81     |
# |    critic_loss     | 0.466    |
# |    ent_coef        | 0.00718  |
# |    ent_coef_loss   | 1.03     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 98910    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 910      |
# |    ep_rew_mean     | -104     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 39       |
# |    time_elapsed    | 2619     |
# |    total_timesteps | 103187   |
# | train/             |          |
# |    actor_loss      | 2.93     |
# |    critic_loss     | 1.31     |
# |    ent_coef        | 0.00758  |
# |    ent_coef_loss   | 3.62     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 103086   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 962      |
# |    ep_rew_mean     | -102     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 39       |
# |    time_elapsed    | 2758     |
# |    total_timesteps | 108585   |
# | train/             |          |
# |    actor_loss      | 3.09     |
# |    critic_loss     | 0.49     |
# |    ent_coef        | 0.00687  |
# |    ent_coef_loss   | -1.49    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 108484   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 977      |
# |    ep_rew_mean     | -102     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 39       |
# |    time_elapsed    | 2878     |
# |    total_timesteps | 113571   |
# | train/             |          |
# |    actor_loss      | 2.89     |
# |    critic_loss     | 0.506    |
# |    ent_coef        | 0.00628  |
# |    ent_coef_loss   | 0.702    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 113470   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | -99.4    |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 39       |
# |    time_elapsed    | 3026     |
# |    total_timesteps | 119971   |
# | train/             |          |
# |    actor_loss      | 3.62     |
# |    critic_loss     | 0.594    |
# |    ent_coef        | 0.0055   |
# |    ent_coef_loss   | -1.85    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 119870   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.08e+03 |
# |    ep_rew_mean     | -97.1    |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 39       |
# |    time_elapsed    | 3151     |
# |    total_timesteps | 125210   |
# | train/             |          |
# |    actor_loss      | 2.37     |
# |    critic_loss     | 0.3      |
# |    ent_coef        | 0.005    |
# |    ent_coef_loss   | -0.0211  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 125109   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | -95      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 39       |
# |    time_elapsed    | 3299     |
# |    total_timesteps | 131610   |
# | train/             |          |
# |    actor_loss      | 3.52     |
# |    critic_loss     | 0.688    |
# |    ent_coef        | 0.00511  |
# |    ent_coef_loss   | 0.498    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 131509   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | -93.7    |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 40       |
# |    time_elapsed    | 3449     |
# |    total_timesteps | 138010   |
# | train/             |          |
# |    actor_loss      | 3.41     |
# |    critic_loss     | 1.01     |
# |    ent_coef        | 0.00501  |
# |    ent_coef_loss   | 1.96     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 137909   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.07e+03 |
# |    ep_rew_mean     | -93.6    |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 40       |
# |    time_elapsed    | 3536     |
# |    total_timesteps | 141793   |
# | train/             |          |
# |    actor_loss      | 3.9      |
# |    critic_loss     | 0.307    |
# |    ent_coef        | 0.00443  |
# |    ent_coef_loss   | -0.714   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 141692   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | -91.3    |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 40       |
# |    time_elapsed    | 3687     |
# |    total_timesteps | 148193   |
# | train/             |          |
# |    actor_loss      | 4.15     |
# |    critic_loss     | 0.307    |
# |    ent_coef        | 0.00465  |
# |    ent_coef_loss   | 1.68     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 148092   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.15e+03 |
# |    ep_rew_mean     | -90      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 40       |
# |    time_elapsed    | 3823     |
# |    total_timesteps | 154029   |
# | train/             |          |
# |    actor_loss      | 3.08     |
# |    critic_loss     | 0.201    |
# |    ent_coef        | 0.00428  |
# |    ent_coef_loss   | -0.324   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 153928   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.16e+03 |
# |    ep_rew_mean     | -89.3    |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 40       |
# |    time_elapsed    | 3926     |
# |    total_timesteps | 158456   |
# | train/             |          |
# |    actor_loss      | 2.99     |
# |    critic_loss     | 0.777    |
# |    ent_coef        | 0.00432  |
# |    ent_coef_loss   | 0.168    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 158355   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.22e+03 |
# |    ep_rew_mean     | -87.2    |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 40       |
# |    time_elapsed    | 4074     |
# |    total_timesteps | 164856   |
# | train/             |          |
# |    actor_loss      | 4.46     |
# |    critic_loss     | 0.452    |
# |    ent_coef        | 0.00483  |
# |    ent_coef_loss   | -0.131   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 164755   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -86.9    |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 40       |
# |    time_elapsed    | 4187     |
# |    total_timesteps | 169755   |
# | train/             |          |
# |    actor_loss      | 3.62     |
# |    critic_loss     | 0.264    |
# |    ent_coef        | 0.00356  |
# |    ent_coef_loss   | -2.45    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 169654   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -86.5    |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 40       |
# |    time_elapsed    | 4284     |
# |    total_timesteps | 173847   |
# | train/             |          |
# |    actor_loss      | 4.16     |
# |    critic_loss     | 0.236    |
# |    ent_coef        | 0.00359  |
# |    ent_coef_loss   | -1.76    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 173746   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.24e+03 |
# |    ep_rew_mean     | -84.9    |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 40       |
# |    time_elapsed    | 4405     |
# |    total_timesteps | 179083   |
# | train/             |          |
# |    actor_loss      | 4.36     |
# |    critic_loss     | 0.587    |
# |    ent_coef        | 0.00372  |
# |    ent_coef_loss   | 1.22     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 178982   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.27e+03 |
# |    ep_rew_mean     | -82.9    |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 40       |
# |    time_elapsed    | 4554     |
# |    total_timesteps | 185483   |
# | train/             |          |
# |    actor_loss      | 4.03     |
# |    critic_loss     | 1.03     |
# |    ent_coef        | 0.00367  |
# |    ent_coef_loss   | 1.32     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 185382   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.27e+03 |
# |    ep_rew_mean     | -81.9    |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 40       |
# |    time_elapsed    | 4704     |
# |    total_timesteps | 191883   |
# | train/             |          |
# |    actor_loss      | 4.61     |
# |    critic_loss     | 0.344    |
# |    ent_coef        | 0.00374  |
# |    ent_coef_loss   | 0.846    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 191782   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.27e+03 |
# |    ep_rew_mean     | -81.6    |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 40       |
# |    time_elapsed    | 4837     |
# |    total_timesteps | 197550   |
# | train/             |          |
# |    actor_loss      | 3.12     |
# |    critic_loss     | 0.188    |
# |    ent_coef        | 0.00357  |
# |    ent_coef_loss   | -0.856   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 197449   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.29e+03 |
# |    ep_rew_mean     | -80.6    |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 40       |
# |    time_elapsed    | 4959     |
# |    total_timesteps | 202546   |
# | train/             |          |
# |    actor_loss      | 2.96     |
# |    critic_loss     | 0.204    |
# |    ent_coef        | 0.00354  |
# |    ent_coef_loss   | 0.0737   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 202445   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.31e+03 |
# |    ep_rew_mean     | -78.9    |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 40       |
# |    time_elapsed    | 5077     |
# |    total_timesteps | 207332   |
# | train/             |          |
# |    actor_loss      | 3.32     |
# |    critic_loss     | 0.127    |
# |    ent_coef        | 0.00328  |
# |    ent_coef_loss   | -1.39    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 207231   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.33e+03 |
# |    ep_rew_mean     | -77      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 40       |
# |    time_elapsed    | 5199     |
# |    total_timesteps | 212586   |
# | train/             |          |
# |    actor_loss      | 4.43     |
# |    critic_loss     | 0.364    |
# |    ent_coef        | 0.00341  |
# |    ent_coef_loss   | 1.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 212485   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.33e+03 |
# |    ep_rew_mean     | -75.9    |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 40       |
# |    time_elapsed    | 5347     |
# |    total_timesteps | 218986   |
# | train/             |          |
# |    actor_loss      | 3.38     |
# |    critic_loss     | 0.241    |
# |    ent_coef        | 0.00355  |
# |    ent_coef_loss   | -0.138   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 218885   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.37e+03 |
# |    ep_rew_mean     | -71.9    |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 41       |
# |    time_elapsed    | 5494     |
# |    total_timesteps | 225386   |
# | train/             |          |
# |    actor_loss      | 3.59     |
# |    critic_loss     | 0.355    |
# |    ent_coef        | 0.00296  |
# |    ent_coef_loss   | -0.555   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 225285   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.38e+03 |
# |    ep_rew_mean     | -70.4    |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 41       |
# |    time_elapsed    | 5629     |
# |    total_timesteps | 231189   |
# | train/             |          |
# |    actor_loss      | 4.3      |
# |    critic_loss     | 0.227    |
# |    ent_coef        | 0.00284  |
# |    ent_coef_loss   | 0.751    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 231088   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.38e+03 |
# |    ep_rew_mean     | -69.1    |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 41       |
# |    time_elapsed    | 5754     |
# |    total_timesteps | 236579   |
# | train/             |          |
# |    actor_loss      | 3.36     |
# |    critic_loss     | 0.301    |
# |    ent_coef        | 0.00298  |
# |    ent_coef_loss   | 2.85     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 236478   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.4e+03  |
# |    ep_rew_mean     | -67.1    |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 41       |
# |    time_elapsed    | 5903     |
# |    total_timesteps | 242979   |
# | train/             |          |
# |    actor_loss      | 2.76     |
# |    critic_loss     | 0.297    |
# |    ent_coef        | 0.00281  |
# |    ent_coef_loss   | -0.988   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 242878   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.38e+03 |
# |    ep_rew_mean     | -67.6    |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 41       |
# |    time_elapsed    | 5980     |
# |    total_timesteps | 246300   |
# | train/             |          |
# |    actor_loss      | 4.52     |
# |    critic_loss     | 0.481    |
# |    ent_coef        | 0.00313  |
# |    ent_coef_loss   | 0.416    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 246199   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.37e+03 |
# |    ep_rew_mean     | -67.6    |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 41       |
# |    time_elapsed    | 6076     |
# |    total_timesteps | 250488   |
# | train/             |          |
# |    actor_loss      | 2.93     |
# |    critic_loss     | 0.469    |
# |    ent_coef        | 0.00298  |
# |    ent_coef_loss   | -1.52    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 250387   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.36e+03 |
# |    ep_rew_mean     | -68.2    |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 41       |
# |    time_elapsed    | 6206     |
# |    total_timesteps | 256027   |
# | train/             |          |
# |    actor_loss      | 3.32     |
# |    critic_loss     | 0.214    |
# |    ent_coef        | 0.00294  |
# |    ent_coef_loss   | -0.879   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 255926   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.37e+03 |
# |    ep_rew_mean     | -68      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 41       |
# |    time_elapsed    | 6354     |
# |    total_timesteps | 262427   |
# | train/             |          |
# |    actor_loss      | 2.12     |
# |    critic_loss     | 0.0883   |
# |    ent_coef        | 0.00307  |
# |    ent_coef_loss   | -1.02    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 262326   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.37e+03 |
# |    ep_rew_mean     | -69      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 41       |
# |    time_elapsed    | 6487     |
# |    total_timesteps | 268228   |
# | train/             |          |
# |    actor_loss      | 3.28     |
# |    critic_loss     | 0.148    |
# |    ent_coef        | 0.00291  |
# |    ent_coef_loss   | -0.652   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 268127   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.35e+03 |
# |    ep_rew_mean     | -70      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 41       |
# |    time_elapsed    | 6595     |
# |    total_timesteps | 272905   |
# | train/             |          |
# |    actor_loss      | 3.37     |
# |    critic_loss     | 0.183    |
# |    ent_coef        | 0.00301  |
# |    ent_coef_loss   | -1.65    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 272804   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.33e+03 |
# |    ep_rew_mean     | -70.2    |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 41       |
# |    time_elapsed    | 6647     |
# |    total_timesteps | 275147   |
# | train/             |          |
# |    actor_loss      | 3.12     |
# |    critic_loss     | 0.299    |
# |    ent_coef        | 0.00304  |
# |    ent_coef_loss   | 1.31     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 275046   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | -71.4    |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 41       |
# |    time_elapsed    | 6769     |
# |    total_timesteps | 280096   |
# | train/             |          |
# |    actor_loss      | 3.11     |
# |    critic_loss     | 0.413    |
# |    ent_coef        | 0.00355  |
# |    ent_coef_loss   | -0.352   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 279995   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | -70.5    |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 41       |
# |    time_elapsed    | 6919     |
# |    total_timesteps | 286496   |
# | train/             |          |
# |    actor_loss      | 4.7      |
# |    critic_loss     | 1.19     |
# |    ent_coef        | 0.00321  |
# |    ent_coef_loss   | 1.75     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 286395   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | -70.4    |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 41       |
# |    time_elapsed    | 7016     |
# |    total_timesteps | 290633   |
# | train/             |          |
# |    actor_loss      | 3.97     |
# |    critic_loss     | 0.539    |
# |    ent_coef        | 0.00304  |
# |    ent_coef_loss   | -1.27    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 290532   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.29e+03 |
# |    ep_rew_mean     | -72.4    |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 41       |
# |    time_elapsed    | 7094     |
# |    total_timesteps | 294040   |
# | train/             |          |
# |    actor_loss      | 3.9      |
# |    critic_loss     | 1.23     |
# |    ent_coef        | 0.00289  |
# |    ent_coef_loss   | 2.32     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 293939   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.27e+03 |
# |    ep_rew_mean     | -73.8    |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 41       |
# |    time_elapsed    | 7153     |
# |    total_timesteps | 296583   |
# | train/             |          |
# |    actor_loss      | 4.39     |
# |    critic_loss     | 0.412    |
# |    ent_coef        | 0.00313  |
# |    ent_coef_loss   | 2.06     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 296482   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.29e+03 |
# |    ep_rew_mean     | -72.1    |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 41       |
# |    time_elapsed    | 7304     |
# |    total_timesteps | 302983   |
# | train/             |          |
# |    actor_loss      | 3.6      |
# |    critic_loss     | 0.206    |
# |    ent_coef        | 0.00318  |
# |    ent_coef_loss   | -1.19    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 302882   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.29e+03 |
# |    ep_rew_mean     | -71.8    |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 41       |
# |    time_elapsed    | 7436     |
# |    total_timesteps | 308010   |
# | train/             |          |
# |    actor_loss      | 3.6      |
# |    critic_loss     | 0.162    |
# |    ent_coef        | 0.00328  |
# |    ent_coef_loss   | -0.0739  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 307909   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.29e+03 |
# |    ep_rew_mean     | -70.4    |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 41       |
# |    time_elapsed    | 7598     |
# |    total_timesteps | 314410   |
# | train/             |          |
# |    actor_loss      | 3.1      |
# |    critic_loss     | 0.17     |
# |    ent_coef        | 0.00335  |
# |    ent_coef_loss   | -2.19    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 314309   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.29e+03 |
# |    ep_rew_mean     | -70.4    |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 41       |
# |    time_elapsed    | 7748     |
# |    total_timesteps | 320810   |
# | train/             |          |
# |    actor_loss      | 3.88     |
# |    critic_loss     | 0.16     |
# |    ent_coef        | 0.0031   |
# |    ent_coef_loss   | -2.28    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 320709   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.3e+03  |
# |    ep_rew_mean     | -69.3    |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 41       |
# |    time_elapsed    | 7897     |
# |    total_timesteps | 327210   |
# | train/             |          |
# |    actor_loss      | 3.63     |
# |    critic_loss     | 0.527    |
# |    ent_coef        | 0.00297  |
# |    ent_coef_loss   | -0.774   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 327109   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.31e+03 |
# |    ep_rew_mean     | -67.9    |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 41       |
# |    time_elapsed    | 8048     |
# |    total_timesteps | 333610   |
# | train/             |          |
# |    actor_loss      | 3.92     |
# |    critic_loss     | 0.406    |
# |    ent_coef        | 0.00277  |
# |    ent_coef_loss   | -0.482   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 333509   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.33e+03 |
# |    ep_rew_mean     | -66.6    |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 41       |
# |    time_elapsed    | 8201     |
# |    total_timesteps | 340010   |
# | train/             |          |
# |    actor_loss      | 2.48     |
# |    critic_loss     | 0.222    |
# |    ent_coef        | 0.00293  |
# |    ent_coef_loss   | -2.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 339909   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.34e+03 |
# |    ep_rew_mean     | -65.7    |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 41       |
# |    time_elapsed    | 8351     |
# |    total_timesteps | 346410   |
# | train/             |          |
# |    actor_loss      | 3.06     |
# |    critic_loss     | 0.241    |
# |    ent_coef        | 0.00322  |
# |    ent_coef_loss   | 1.26     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 346309   |
# ...
# |    fps             | 42       |
# |    time_elapsed    | 20024    |
# |    total_timesteps | 842202   |
# | train/             |          |
# |    actor_loss      | 3.21     |
# |    critic_loss     | 0.208    |
# |    ent_coef        | 0.00303  |
# |    ent_coef_loss   | 0.617    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 842101   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.42e+03 |
# |    ep_rew_mean     | -40.9    |
# | time/              |          |
# |    episodes        | 692      |
# |    fps             | 42       |
# |    time_elapsed    | 20171    |
# |    total_timesteps | 848472   |
# | train/             |          |
# |    actor_loss      | 3.6      |
# |    critic_loss     | 0.334    |
# |    ent_coef        | 0.00317  |
# |    ent_coef_loss   | -0.305   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 848371   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.42e+03 |
# |    ep_rew_mean     | -41.3    |
# | time/              |          |
# |    episodes        | 696      |
# |    fps             | 42       |
# |    time_elapsed    | 20317    |
# |    total_timesteps | 854593   |
# | train/             |          |
# |    actor_loss      | 3.26     |
# |    critic_loss     | 0.475    |
# |    ent_coef        | 0.0029   |
# |    ent_coef_loss   | 1.16     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 854492   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.41e+03 |
# |    ep_rew_mean     | -43.4    |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 42       |
# |    time_elapsed    | 20435    |
# |    total_timesteps | 859622   |
# | train/             |          |
# |    actor_loss      | 3.72     |
# |    critic_loss     | 0.32     |
# |    ent_coef        | 0.00273  |
# |    ent_coef_loss   | -1.33    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 859521   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.38e+03 |
# |    ep_rew_mean     | -44.4    |
# | time/              |          |
# |    episodes        | 704      |
# |    fps             | 42       |
# |    time_elapsed    | 20529    |
# |    total_timesteps | 863591   |
# | train/             |          |
# |    actor_loss      | 4.42     |
# |    critic_loss     | 0.297    |
# |    ent_coef        | 0.00301  |
# |    ent_coef_loss   | 1.7      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 863490   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.37e+03 |
# |    ep_rew_mean     | -44.4    |
# | time/              |          |
# |    episodes        | 708      |
# |    fps             | 42       |
# |    time_elapsed    | 20655    |
# |    total_timesteps | 868918   |
# | train/             |          |
# |    actor_loss      | 3.18     |
# |    critic_loss     | 0.161    |
# |    ent_coef        | 0.00305  |
# |    ent_coef_loss   | -0.964   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 868817   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.39e+03 |
# |    ep_rew_mean     | -44.3    |
# | time/              |          |
# |    episodes        | 712      |
# |    fps             | 42       |
# |    time_elapsed    | 20806    |
# |    total_timesteps | 875318   |
# | train/             |          |
# |    actor_loss      | 3.35     |
# |    critic_loss     | 0.172    |
# |    ent_coef        | 0.00293  |
# |    ent_coef_loss   | 0.951    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 875217   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.39e+03 |
# |    ep_rew_mean     | -44.6    |
# | time/              |          |
# |    episodes        | 716      |
# |    fps             | 42       |
# |    time_elapsed    | 20927    |
# |    total_timesteps | 880399   |
# | train/             |          |
# |    actor_loss      | 3.68     |
# |    critic_loss     | 1.03     |
# |    ent_coef        | 0.00292  |
# |    ent_coef_loss   | 1.71     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 880298   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.39e+03 |
# |    ep_rew_mean     | -43.5    |
# | time/              |          |
# |    episodes        | 720      |
# |    fps             | 42       |
# |    time_elapsed    | 21082    |
# |    total_timesteps | 886799   |
# | train/             |          |
# |    actor_loss      | 3.84     |
# |    critic_loss     | 1.27     |
# |    ent_coef        | 0.00293  |
# |    ent_coef_loss   | 1.94     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 886698   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.38e+03 |
# |    ep_rew_mean     | -44.2    |
# | time/              |          |
# |    episodes        | 724      |
# |    fps             | 42       |
# |    time_elapsed    | 21207    |
# |    total_timesteps | 891987   |
# | train/             |          |
# |    actor_loss      | 3.4      |
# |    critic_loss     | 0.236    |
# |    ent_coef        | 0.00327  |
# |    ent_coef_loss   | -2.06    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 891886   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.4e+03  |
# |    ep_rew_mean     | -43.3    |
# | time/              |          |
# |    episodes        | 728      |
# |    fps             | 42       |
# |    time_elapsed    | 21358    |
# |    total_timesteps | 898387   |
# | train/             |          |
# |    actor_loss      | 3.54     |
# |    critic_loss     | 0.286    |
# |    ent_coef        | 0.00307  |
# |    ent_coef_loss   | -3.08    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 898286   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.39e+03 |
# |    ep_rew_mean     | -43.3    |
# | time/              |          |
# |    episodes        | 732      |
# |    fps             | 42       |
# |    time_elapsed    | 21496    |
# |    total_timesteps | 904178   |
# | train/             |          |
# |    actor_loss      | 3.22     |
# |    critic_loss     | 0.234    |
# |    ent_coef        | 0.00334  |
# |    ent_coef_loss   | -2.02    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 904077   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.38e+03 |
# |    ep_rew_mean     | -44.1    |
# | time/              |          |
# |    episodes        | 736      |
# |    fps             | 42       |
# |    time_elapsed    | 21615    |
# |    total_timesteps | 909206   |
# | train/             |          |
# |    actor_loss      | 3.87     |
# |    critic_loss     | 0.276    |
# |    ent_coef        | 0.00296  |
# |    ent_coef_loss   | 0.661    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 909105   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.37e+03 |
# |    ep_rew_mean     | -44.7    |
# | time/              |          |
# |    episodes        | 740      |
# |    fps             | 42       |
# |    time_elapsed    | 21710    |
# |    total_timesteps | 913234   |
# | train/             |          |
# |    actor_loss      | 2.5      |
# |    critic_loss     | 0.177    |
# |    ent_coef        | 0.00325  |
# |    ent_coef_loss   | 1.91     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 913133   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.37e+03 |
# |    ep_rew_mean     | -44.4    |
# | time/              |          |
# |    episodes        | 744      |
# |    fps             | 42       |
# |    time_elapsed    | 21836    |
# |    total_timesteps | 918534   |
# | train/             |          |
# |    actor_loss      | 2.99     |
# |    critic_loss     | 0.184    |
# |    ent_coef        | 0.00326  |
# |    ent_coef_loss   | 2.54     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 918433   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.37e+03 |
# |    ep_rew_mean     | -45.1    |
# | time/              |          |
# |    episodes        | 748      |
# |    fps             | 42       |
# |    time_elapsed    | 21988    |
# |    total_timesteps | 924934   |
# | train/             |          |
# |    actor_loss      | 3.9      |
# |    critic_loss     | 0.557    |
# |    ent_coef        | 0.00342  |
# |    ent_coef_loss   | -0.828   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 924833   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.36e+03 |
# |    ep_rew_mean     | -44.2    |
# | time/              |          |
# |    episodes        | 752      |
# |    fps             | 42       |
# |    time_elapsed    | 22118    |
# |    total_timesteps | 930383   |
# | train/             |          |
# |    actor_loss      | 2.73     |
# |    critic_loss     | 0.242    |
# |    ent_coef        | 0.00325  |
# |    ent_coef_loss   | 0.38     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 930282   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.37e+03 |
# |    ep_rew_mean     | -42.6    |
# | time/              |          |
# |    episodes        | 756      |
# |    fps             | 42       |
# |    time_elapsed    | 22271    |
# |    total_timesteps | 936783   |
# | train/             |          |
# |    actor_loss      | 2.91     |
# |    critic_loss     | 0.221    |
# |    ent_coef        | 0.00286  |
# |    ent_coef_loss   | -0.856   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 936682   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.36e+03 |
# |    ep_rew_mean     | -44.2    |
# | time/              |          |
# |    episodes        | 760      |
# |    fps             | 42       |
# |    time_elapsed    | 22399    |
# |    total_timesteps | 942169   |
# | train/             |          |
# |    actor_loss      | 3.47     |
# |    critic_loss     | 0.272    |
# |    ent_coef        | 0.00296  |
# |    ent_coef_loss   | -0.305   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 942068   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.38e+03 |
# |    ep_rew_mean     | -43.2    |
# | time/              |          |
# |    episodes        | 764      |
# |    fps             | 42       |
# |    time_elapsed    | 22541    |
# |    total_timesteps | 948200   |
# | train/             |          |
# |    actor_loss      | 3.58     |
# |    critic_loss     | 0.164    |
# |    ent_coef        | 0.00298  |
# |    ent_coef_loss   | 0.425    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 948099   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.39e+03 |
# |    ep_rew_mean     | -41.6    |
# | time/              |          |
# |    episodes        | 768      |
# |    fps             | 42       |
# |    time_elapsed    | 22693    |
# |    total_timesteps | 954600   |
# | train/             |          |
# |    actor_loss      | 3.54     |
# |    critic_loss     | 0.11     |
# |    ent_coef        | 0.00292  |
# |    ent_coef_loss   | -1.82    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 954499   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.41e+03 |
# |    ep_rew_mean     | -41.2    |
# | time/              |          |
# |    episodes        | 772      |
# |    fps             | 42       |
# |    time_elapsed    | 22816    |
# |    total_timesteps | 959759   |
# | train/             |          |
# |    actor_loss      | 3.36     |
# |    critic_loss     | 0.465    |
# |    ent_coef        | 0.003    |
# |    ent_coef_loss   | -1.06    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 959658   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.4e+03  |
# |    ep_rew_mean     | -43.1    |
# | time/              |          |
# |    episodes        | 776      |
# |    fps             | 42       |
# |    time_elapsed    | 22933    |
# |    total_timesteps | 964682   |
# | train/             |          |
# |    actor_loss      | 3.12     |
# |    critic_loss     | 0.217    |
# |    ent_coef        | 0.003    |
# |    ent_coef_loss   | -0.102   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 964581   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.4e+03  |
# |    ep_rew_mean     | -43.9    |
# | time/              |          |
# |    episodes        | 780      |
# |    fps             | 42       |
# |    time_elapsed    | 23065    |
# |    total_timesteps | 970248   |
# | train/             |          |
# |    actor_loss      | 4.18     |
# |    critic_loss     | 0.245    |
# |    ent_coef        | 0.00309  |
# |    ent_coef_loss   | -0.871   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 970147   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.39e+03 |
# |    ep_rew_mean     | -43      |
# | time/              |          |
# |    episodes        | 784      |
# |    fps             | 42       |
# |    time_elapsed    | 23205    |
# |    total_timesteps | 976158   |
# | train/             |          |
# |    actor_loss      | 2.98     |
# |    critic_loss     | 0.353    |
# |    ent_coef        | 0.00315  |
# |    ent_coef_loss   | -0.541   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 976057   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.4e+03  |
# |    ep_rew_mean     | -41.6    |
# | time/              |          |
# |    episodes        | 788      |
# |    fps             | 42       |
# |    time_elapsed    | 23359    |
# |    total_timesteps | 982558   |
# | train/             |          |
# |    actor_loss      | 3.42     |
# |    critic_loss     | 0.237    |
# |    ent_coef        | 0.00317  |
# |    ent_coef_loss   | 0.12     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 982457   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.39e+03 |
# |    ep_rew_mean     | -41.5    |
# | time/              |          |
# |    episodes        | 792      |
# |    fps             | 42       |
# |    time_elapsed    | 23476    |
# |    total_timesteps | 987472   |
# | train/             |          |
# |    actor_loss      | 3.21     |
# |    critic_loss     | 0.263    |
# |    ent_coef        | 0.00305  |
# |    ent_coef_loss   | -1.35    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 987371   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.39e+03 |
# |    ep_rew_mean     | -40.7    |
# | time/              |          |
# |    episodes        | 796      |
# |    fps             | 42       |
# |    time_elapsed    | 23629    |
# |    total_timesteps | 993872   |
# | train/             |          |
# |    actor_loss      | 3.22     |
# |    critic_loss     | 0.256    |
# |    ent_coef        | 0.00307  |
# |    ent_coef_loss   | 1.14     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 993771   |
# ---------------------------------

# %%
sac_path = os.path.join('Training', 'Saved Models', 'SAC_Walker_model_1M')

# %%
model.save(sac_path)
