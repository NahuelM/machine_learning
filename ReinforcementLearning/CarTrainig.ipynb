# %%
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %%
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env

# %%
from gym.envs import box2d

# %%
environment_name = "CarRacing-v2"

# %%
env = gym.make(environment_name)

# %%
vec_env = make_vec_env(environment_name, n_envs=4)

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = PPO("CnnPolicy", vec_env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=1000000)
# Out:
# Logging to Training\Logs\PPO_3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -56.4    |
# | time/              |          |
# |    fps             | 58       |
# |    iterations      | 1        |
# |    time_elapsed    | 141      |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -54.8       |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 2           |
# |    time_elapsed         | 365         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006901572 |
# |    clip_fraction        | 0.0777      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.0005      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.112       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00706    |
# |    std                  | 0.986       |
# |    value_loss           | 0.564       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52.8       |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 3           |
# |    time_elapsed         | 604         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009882077 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.168       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.11        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 0.972       |
# |    value_loss           | 0.333       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 4           |
# |    time_elapsed         | 842         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.013679367 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.455       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0644      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.956       |
# |    value_loss           | 0.282       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48.2       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 5           |
# |    time_elapsed         | 1098        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.020125084 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.465       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.056       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0219     |
# |    std                  | 0.943       |
# |    value_loss           | 0.252       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -46.3       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 6           |
# |    time_elapsed         | 1302        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.023704074 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.04       |
# |    explained_variance   | 0.491       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0032      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0251     |
# |    std                  | 0.927       |
# |    value_loss           | 0.208       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -45.7      |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 7          |
# |    time_elapsed         | 1552       |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.02125769 |
# |    clip_fraction        | 0.201      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4         |
# |    explained_variance   | 0.51       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0392     |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0238    |
# |    std                  | 0.914      |
# |    value_loss           | 0.258      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -46.4       |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 8           |
# |    time_elapsed         | 1788        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.032556996 |
# |    clip_fraction        | 0.271       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.97       |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0742      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0318     |
# |    std                  | 0.909       |
# |    value_loss           | 0.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -45.8       |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 9           |
# |    time_elapsed         | 2025        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.036739066 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.92       |
# |    explained_variance   | 0.694       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00997    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0381     |
# |    std                  | 0.89        |
# |    value_loss           | 0.133       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -44.4      |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 10         |
# |    time_elapsed         | 2264       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.04562792 |
# |    clip_fraction        | 0.302      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.87      |
# |    explained_variance   | 0.787      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0415    |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0367    |
# |    std                  | 0.876      |
# |    value_loss           | 0.16       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -42.3      |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 11         |
# |    time_elapsed         | 2508       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.04881754 |
# |    clip_fraction        | 0.324      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.79      |
# |    explained_variance   | 0.854      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.000737   |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0389    |
# |    std                  | 0.849      |
# |    value_loss           | 0.174      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -41        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 12         |
# |    time_elapsed         | 2748       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.05605102 |
# |    clip_fraction        | 0.358      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.7       |
# |    explained_variance   | 0.876      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0191    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0434    |
# |    std                  | 0.827      |
# |    value_loss           | 0.178      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -38.1      |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 13         |
# |    time_elapsed         | 2991       |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.07385306 |
# |    clip_fraction        | 0.383      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.63      |
# |    explained_variance   | 0.879      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0197    |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0477    |
# |    std                  | 0.806      |
# |    value_loss           | 0.212      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -34.8     |
# | time/                   |           |
# |    fps                  | 35        |
# |    iterations           | 14        |
# |    time_elapsed         | 3242      |
# |    total_timesteps      | 114688    |
# | train/                  |           |
# |    approx_kl            | 0.0724787 |
# |    clip_fraction        | 0.39      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.54     |
# |    explained_variance   | 0.896     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00151   |
# |    n_updates            | 130       |
# |    policy_gradient_loss | -0.05     |
# |    std                  | 0.787     |
# |    value_loss           | 0.254     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -27.2      |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 15         |
# |    time_elapsed         | 3500       |
# |    total_timesteps      | 122880     |
# | train/                  |            |
# |    approx_kl            | 0.08732895 |
# |    clip_fraction        | 0.42       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.47      |
# |    explained_variance   | 0.916      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0505    |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0493    |
# |    std                  | 0.767      |
# |    value_loss           | 0.255      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -23.9      |
# | time/                   |            |
# |    fps                  | 34         |
# |    iterations           | 16         |
# |    time_elapsed         | 3758       |
# |    total_timesteps      | 131072     |
# | train/                  |            |
# |    approx_kl            | 0.09474153 |
# |    clip_fraction        | 0.442      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.39      |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0634    |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0502    |
# |    std                  | 0.747      |
# |    value_loss           | 0.34       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -17.9      |
# | time/                   |            |
# |    fps                  | 34         |
# |    iterations           | 17         |
# |    time_elapsed         | 3979       |
# |    total_timesteps      | 139264     |
# | train/                  |            |
# |    approx_kl            | 0.10472712 |
# |    clip_fraction        | 0.476      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.31      |
# |    explained_variance   | 0.937      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0237    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0493    |
# |    std                  | 0.73       |
# |    value_loss           | 0.258      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -11.2      |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 18         |
# |    time_elapsed         | 4185       |
# |    total_timesteps      | 147456     |
# | train/                  |            |
# |    approx_kl            | 0.09393458 |
# |    clip_fraction        | 0.456      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.24      |
# |    explained_variance   | 0.944      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0145    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0464    |
# |    std                  | 0.713      |
# |    value_loss           | 0.38       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 3.43      |
# | time/                   |           |
# |    fps                  | 35        |
# |    iterations           | 19        |
# |    time_elapsed         | 4391      |
# |    total_timesteps      | 155648    |
# | train/                  |           |
# |    approx_kl            | 0.0807906 |
# |    clip_fraction        | 0.445     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.15     |
# |    explained_variance   | 0.926     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00703  |
# |    n_updates            | 180       |
# |    policy_gradient_loss | -0.0445   |
# |    std                  | 0.693     |
# |    value_loss           | 0.584     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 15.3       |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 20         |
# |    time_elapsed         | 4604       |
# |    total_timesteps      | 163840     |
# | train/                  |            |
# |    approx_kl            | 0.11340524 |
# |    clip_fraction        | 0.467      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.06      |
# |    explained_variance   | 0.899      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0855     |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0438    |
# |    std                  | 0.672      |
# |    value_loss           | 0.917      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 41.9       |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 21         |
# |    time_elapsed         | 4838       |
# |    total_timesteps      | 172032     |
# | train/                  |            |
# |    approx_kl            | 0.13607009 |
# |    clip_fraction        | 0.525      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.96      |
# |    explained_variance   | 0.92       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0227     |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0496    |
# |    std                  | 0.65       |
# |    value_loss           | 0.661      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 61.5      |
# | time/                   |           |
# |    fps                  | 35        |
# |    iterations           | 22        |
# |    time_elapsed         | 5054      |
# |    total_timesteps      | 180224    |
# | train/                  |           |
# |    approx_kl            | 0.1544066 |
# |    clip_fraction        | 0.526     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.86     |
# |    explained_variance   | 0.911     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0302    |
# |    n_updates            | 210       |
# |    policy_gradient_loss | -0.047    |
# |    std                  | 0.631     |
# |    value_loss           | 0.793     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 77.4       |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 23         |
# |    time_elapsed         | 5268       |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.21343787 |
# |    clip_fraction        | 0.547      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.77      |
# |    explained_variance   | 0.915      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0837     |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0499    |
# |    std                  | 0.609      |
# |    value_loss           | 1.02       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 101        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 24         |
# |    time_elapsed         | 5481       |
# |    total_timesteps      | 196608     |
# | train/                  |            |
# |    approx_kl            | 0.45649147 |
# |    clip_fraction        | 0.582      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.67      |
# |    explained_variance   | 0.939      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.165      |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0412    |
# |    std                  | 0.592      |
# |    value_loss           | 0.878      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 125        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 25         |
# |    time_elapsed         | 5696       |
# |    total_timesteps      | 204800     |
# | train/                  |            |
# |    approx_kl            | 0.18315458 |
# |    clip_fraction        | 0.578      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.59      |
# |    explained_variance   | 0.778      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.207      |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0301    |
# |    std                  | 0.58       |
# |    value_loss           | 1.45       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 152        |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 26         |
# |    time_elapsed         | 5910       |
# |    total_timesteps      | 212992     |
# | train/                  |            |
# |    approx_kl            | 0.19697289 |
# |    clip_fraction        | 0.583      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.52      |
# |    explained_variance   | 0.828      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0305     |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.037     |
# |    std                  | 0.567      |
# |    value_loss           | 1.42       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 174        |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 27         |
# |    time_elapsed         | 6119       |
# |    total_timesteps      | 221184     |
# | train/                  |            |
# |    approx_kl            | 0.21359473 |
# |    clip_fraction        | 0.596      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.46      |
# |    explained_variance   | 0.777      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.119      |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0299    |
# |    std                  | 0.555      |
# |    value_loss           | 1.8        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 201        |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 28         |
# |    time_elapsed         | 6328       |
# |    total_timesteps      | 229376     |
# | train/                  |            |
# |    approx_kl            | 0.40620995 |
# |    clip_fraction        | 0.615      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.39      |
# |    explained_variance   | 0.859      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.09       |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0331    |
# |    std                  | 0.542      |
# |    value_loss           | 1.38       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 227        |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 29         |
# |    time_elapsed         | 6537       |
# |    total_timesteps      | 237568     |
# | train/                  |            |
# |    approx_kl            | 0.42386964 |
# |    clip_fraction        | 0.641      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.3       |
# |    explained_variance   | 0.867      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0652     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0312    |
# |    std                  | 0.525      |
# |    value_loss           | 1.35       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 251       |
# | time/                   |           |
# |    fps                  | 36        |
# |    iterations           | 30        |
# |    time_elapsed         | 6748      |
# |    total_timesteps      | 245760    |
# | train/                  |           |
# |    approx_kl            | 0.8490465 |
# |    clip_fraction        | 0.631     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.22     |
# |    explained_variance   | 0.872     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.208     |
# |    n_updates            | 290       |
# |    policy_gradient_loss | -0.0317   |
# |    std                  | 0.512     |
# |    value_loss           | 1.42      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 267       |
# | time/                   |           |
# |    fps                  | 36        |
# |    iterations           | 31        |
# |    time_elapsed         | 6958      |
# |    total_timesteps      | 253952    |
# | train/                  |           |
# |    approx_kl            | 4.8337736 |
# |    clip_fraction        | 0.708     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.11     |
# |    explained_variance   | 0.938     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0881    |
# |    n_updates            | 300       |
# |    policy_gradient_loss | -0.0494   |
# |    std                  | 0.491     |
# |    value_loss           | 1.24      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 292       |
# | time/                   |           |
# |    fps                  | 36        |
# |    iterations           | 32        |
# |    time_elapsed         | 7168      |
# |    total_timesteps      | 262144    |
# | train/                  |           |
# |    approx_kl            | 2.7861314 |
# |    clip_fraction        | 0.722     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.02     |
# |    explained_variance   | 0.861     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.296     |
# |    n_updates            | 310       |
# |    policy_gradient_loss | -0.0229   |
# |    std                  | 0.476     |
# |    value_loss           | 2.58      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 316       |
# | time/                   |           |
# |    fps                  | 36        |
# |    iterations           | 33        |
# |    time_elapsed         | 7378      |
# |    total_timesteps      | 270336    |
# | train/                  |           |
# |    approx_kl            | 5.0678797 |
# |    clip_fraction        | 0.749     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.91     |
# |    explained_variance   | 0.899     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.346     |
# |    n_updates            | 320       |
# |    policy_gradient_loss | -0.0116   |
# |    std                  | 0.461     |
# |    value_loss           | 4.24      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 344       |
# | time/                   |           |
# |    fps                  | 36        |
# |    iterations           | 34        |
# |    time_elapsed         | 7589      |
# |    total_timesteps      | 278528    |
# | train/                  |           |
# |    approx_kl            | 1.9876764 |
# |    clip_fraction        | 0.739     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.82     |
# |    explained_variance   | 0.884     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.446     |
# |    n_updates            | 330       |
# |    policy_gradient_loss | -0.013    |
# |    std                  | 0.447     |
# |    value_loss           | 2.78      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 363       |
# | time/                   |           |
# |    fps                  | 36        |
# |    iterations           | 35        |
# |    time_elapsed         | 7827      |
# |    total_timesteps      | 286720    |
# | train/                  |           |
# |    approx_kl            | 3.5912967 |
# |    clip_fraction        | 0.768     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.74     |
# |    explained_variance   | 0.923     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.678     |
# |    n_updates            | 340       |
# |    policy_gradient_loss | 0.0138    |
# |    std                  | 0.438     |
# |    value_loss           | 5.85      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 375       |
# | time/                   |           |
# |    fps                  | 36        |
# |    iterations           | 36        |
# |    time_elapsed         | 8086      |
# |    total_timesteps      | 294912    |
# | train/                  |           |
# |    approx_kl            | 7.6971955 |
# |    clip_fraction        | 0.839     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.66     |
# |    explained_variance   | 0.919     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.716     |
# |    n_updates            | 350       |
# |    policy_gradient_loss | 0.00383   |
# |    std                  | 0.422     |
# |    value_loss           | 3.75      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 373       |
# | time/                   |           |
# |    fps                  | 36        |
# |    iterations           | 37        |
# |    time_elapsed         | 8354      |
# |    total_timesteps      | 303104    |
# | train/                  |           |
# |    approx_kl            | 13.036221 |
# |    clip_fraction        | 0.828     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.53     |
# |    explained_variance   | 0.943     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.593     |
# |    n_updates            | 360       |
# |    policy_gradient_loss | -0.00675  |
# |    std                  | 0.404     |
# |    value_loss           | 3.1       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 358       |
# | time/                   |           |
# |    fps                  | 36        |
# |    iterations           | 38        |
# |    time_elapsed         | 8632      |
# |    total_timesteps      | 311296    |
# | train/                  |           |
# |    approx_kl            | 5.5809717 |
# |    clip_fraction        | 0.789     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.43     |
# |    explained_variance   | 0.964     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.347     |
# |    n_updates            | 370       |
# |    policy_gradient_loss | -0.00627  |
# |    std                  | 0.394     |
# |    value_loss           | 3.19      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 343       |
# | time/                   |           |
# |    fps                  | 35        |
# |    iterations           | 39        |
# |    time_elapsed         | 8885      |
# |    total_timesteps      | 319488    |
# | train/                  |           |
# |    approx_kl            | 17.086788 |
# |    clip_fraction        | 0.871     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.34     |
# |    explained_variance   | 0.942     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.106     |
# |    n_updates            | 380       |
# |    policy_gradient_loss | -0.00423  |
# |    std                  | 0.383     |
# |    value_loss           | 1.87      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1e+03    |
# |    ep_rew_mean          | 346      |
# | time/                   |          |
# |    fps                  | 35       |
# |    iterations           | 40       |
# |    time_elapsed         | 9149     |
# |    total_timesteps      | 327680   |
# | train/                  |          |
# |    approx_kl            | 3.968608 |
# |    clip_fraction        | 0.767    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.31    |
# |    explained_variance   | 0.955    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.527    |
# |    n_updates            | 390      |
# |    policy_gradient_loss | 0.0367   |
# |    std                  | 0.38     |
# |    value_loss           | 4.72     |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1e+03    |
# |    ep_rew_mean          | 358      |
# | time/                   |          |
# |    fps                  | 35       |
# |    iterations           | 41       |
# |    time_elapsed         | 9423     |
# |    total_timesteps      | 335872   |
# | train/                  |          |
# |    approx_kl            | 4.049406 |
# |    clip_fraction        | 0.772    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.25    |
# |    explained_variance   | 0.951    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.628    |
# |    n_updates            | 400      |
# |    policy_gradient_loss | 0.0145   |
# |    std                  | 0.371    |
# |    value_loss           | 5.23     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 338       |
# | time/                   |           |
# |    fps                  | 35        |
# |    iterations           | 42        |
# |    time_elapsed         | 9705      |
# |    total_timesteps      | 344064    |
# | train/                  |           |
# |    approx_kl            | 10.253988 |
# |    clip_fraction        | 0.793     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.18     |
# |    explained_variance   | 0.968     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.691     |
# |    n_updates            | 410       |
# |    policy_gradient_loss | 0.107     |
# |    std                  | 0.36      |
# |    value_loss           | 3.25      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1e+03    |
# |    ep_rew_mean          | 334      |
# | time/                   |          |
# |    fps                  | 35       |
# |    iterations           | 43       |
# |    time_elapsed         | 9988     |
# |    total_timesteps      | 352256   |
# | train/                  |          |
# |    approx_kl            | 9.976572 |
# |    clip_fraction        | 0.812    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.1     |
# |    explained_variance   | 0.953    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.6      |
# |    n_updates            | 420      |
# |    policy_gradient_loss | 0.00517  |
# |    std                  | 0.352    |
# |    value_loss           | 3.2      |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 319       |
# | time/                   |           |
# |    fps                  | 35        |
# |    iterations           | 44        |
# |    time_elapsed         | 10255     |
# |    total_timesteps      | 360448    |
# | train/                  |           |
# |    approx_kl            | 12.865766 |
# |    clip_fraction        | 0.837     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.04     |
# |    explained_variance   | 0.921     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.785     |
# |    n_updates            | 430       |
# |    policy_gradient_loss | 0.0234    |
# |    std                  | 0.347     |
# |    value_loss           | 4.68      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 288       |
# | time/                   |           |
# |    fps                  | 35        |
# |    iterations           | 45        |
# |    time_elapsed         | 10524     |
# |    total_timesteps      | 368640    |
# | train/                  |           |
# |    approx_kl            | 11.519369 |
# |    clip_fraction        | 0.85      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.959    |
# |    explained_variance   | 0.918     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.437     |
# |    n_updates            | 440       |
# |    policy_gradient_loss | 0.0155    |
# |    std                  | 0.335     |
# |    value_loss           | 3.67      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 245       |
# | time/                   |           |
# |    fps                  | 35        |
# |    iterations           | 46        |
# |    time_elapsed         | 10749     |
# |    total_timesteps      | 376832    |
# | train/                  |           |
# |    approx_kl            | 10.822462 |
# |    clip_fraction        | 0.841     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.85     |
# |    explained_variance   | 0.914     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.134     |
# |    n_updates            | 450       |
# |    policy_gradient_loss | 0.0106    |
# |    std                  | 0.323     |
# |    value_loss           | 2.24      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 217       |
# | time/                   |           |
# |    fps                  | 35        |
# |    iterations           | 47        |
# |    time_elapsed         | 10972     |
# |    total_timesteps      | 385024    |
# | train/                  |           |
# |    approx_kl            | 22.368937 |
# |    clip_fraction        | 0.837     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.732    |
# |    explained_variance   | 0.966     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.262     |
# |    n_updates            | 460       |
# |    policy_gradient_loss | 0.0123    |
# |    std                  | 0.312     |
# |    value_loss           | 1.39      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 199       |
# | time/                   |           |
# |    fps                  | 35        |
# |    iterations           | 48        |
# |    time_elapsed         | 11195     |
# |    total_timesteps      | 393216    |
# | train/                  |           |
# |    approx_kl            | 17.919598 |
# |    clip_fraction        | 0.915     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.623    |
# |    explained_variance   | 0.881     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.301     |
# |    n_updates            | 470       |
# |    policy_gradient_loss | -0.01     |
# |    std                  | 0.3       |
# |    value_loss           | 1.63      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 186       |
# | time/                   |           |
# |    fps                  | 35        |
# |    iterations           | 49        |
# |    time_elapsed         | 11422     |
# |    total_timesteps      | 401408    |
# | train/                  |           |
# |    approx_kl            | 18.113071 |
# |    clip_fraction        | 0.893     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.508    |
# |    explained_variance   | 0.918     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.173     |
# |    n_updates            | 480       |
# |    policy_gradient_loss | -0.017    |
# |    std                  | 0.289     |
# |    value_loss           | 1.73      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 193       |
# | time/                   |           |
# |    fps                  | 35        |
# |    iterations           | 50        |
# |    time_elapsed         | 11667     |
# |    total_timesteps      | 409600    |
# | train/                  |           |
# |    approx_kl            | 19.345356 |
# |    clip_fraction        | 0.902     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.394    |
# |    explained_variance   | 0.937     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.55      |
# |    n_updates            | 490       |
# |    policy_gradient_loss | -0.0108   |
# |    std                  | 0.276     |
# |    value_loss           | 1.74      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1e+03    |
# |    ep_rew_mean          | 192      |
# | time/                   |          |
# |    fps                  | 35       |
# |    iterations           | 51       |
# |    time_elapsed         | 11917    |
# |    total_timesteps      | 417792   |
# | train/                  |          |
# |    approx_kl            | 10.79044 |
# |    clip_fraction        | 0.806    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.24    |
# |    explained_variance   | 0.94     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.191    |
# |    n_updates            | 500      |
# |    policy_gradient_loss | 0.329    |
# |    std                  | 0.261    |
# |    value_loss           | 1.52     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 180       |
# | time/                   |           |
# |    fps                  | 35        |
# |    iterations           | 52        |
# |    time_elapsed         | 12146     |
# |    total_timesteps      | 425984    |
# | train/                  |           |
# |    approx_kl            | 10.178359 |
# |    clip_fraction        | 0.86      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.108    |
# |    explained_variance   | 0.938     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.107     |
# |    n_updates            | 510       |
# |    policy_gradient_loss | -0.02     |
# |    std                  | 0.251     |
# |    value_loss           | 1.12      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1e+03    |
# |    ep_rew_mean          | 146      |
# | time/                   |          |
# |    fps                  | 35       |
# |    iterations           | 53       |
# |    time_elapsed         | 12378    |
# |    total_timesteps      | 434176   |
# | train/                  |          |
# |    approx_kl            | 9.801709 |
# |    clip_fraction        | 0.824    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.0252  |
# |    explained_variance   | 0.929    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.246    |
# |    n_updates            | 520      |
# |    policy_gradient_loss | 0.254    |
# |    std                  | 0.246    |
# |    value_loss           | 1.77     |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1e+03    |
# |    ep_rew_mean          | 152      |
# | time/                   |          |
# |    fps                  | 35       |
# |    iterations           | 54       |
# |    time_elapsed         | 12620    |
# |    total_timesteps      | 442368   |
# | train/                  |          |
# |    approx_kl            | 15.98572 |
# |    clip_fraction        | 0.853    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 0.0893   |
# |    explained_variance   | 0.96     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0991   |
# |    n_updates            | 530      |
# |    policy_gradient_loss | -0.0248  |
# |    std                  | 0.236    |
# |    value_loss           | 1.11     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 142       |
# | time/                   |           |
# |    fps                  | 34        |
# |    iterations           | 55        |
# |    time_elapsed         | 12895     |
# |    total_timesteps      | 450560    |
# | train/                  |           |
# |    approx_kl            | 16.616764 |
# |    clip_fraction        | 0.87      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.226     |
# |    explained_variance   | 0.932     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.231     |
# |    n_updates            | 540       |
# |    policy_gradient_loss | -0.0115   |
# |    std                  | 0.224     |
# |    value_loss           | 1.5       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 131       |
# | time/                   |           |
# |    fps                  | 34        |
# |    iterations           | 56        |
# |    time_elapsed         | 13181     |
# |    total_timesteps      | 458752    |
# | train/                  |           |
# |    approx_kl            | 18.634792 |
# |    clip_fraction        | 0.857     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.38      |
# |    explained_variance   | 0.94      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.376     |
# |    n_updates            | 550       |
# |    policy_gradient_loss | -0.0197   |
# |    std                  | 0.215     |
# |    value_loss           | 2.08      |
# ---------------------------------------

# %%
ppo_path = os.path.join('Training', 'Saved Models', 'PPO_Driving_model1M')

# %%
model.save(ppo_path)
