# %%
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %%
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env

# %%
from gym.envs import box2d

# %%
environment_name = "BipedalWalker-v3"

# %%
env = gym.make(environment_name, hardcore=True)

# %%
env.action_space.sample()
# Out:
# array([-0.0092526 ,  0.6516297 , -0.28077862, -0.7503878 ], dtype=float32)

# %%
vec_env = make_vec_env(environment_name, n_envs=4)

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = PPO("MlpPolicy", vec_env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=5000000)
# Out:
# Logging to Training\Logs\PPO_7
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | 275      |
# | time/              |          |
# |    fps             | 1450     |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.34e+03    |
# |    ep_rew_mean          | 274         |
# | time/                   |             |
# |    fps                  | 838         |
# |    iterations           | 2           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.018968243 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.39       |
# |    explained_variance   | 0.651       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.34        |
# |    n_updates            | 1240        |
# |    policy_gradient_loss | -0.00279    |
# |    std                  | 0.446       |
# |    value_loss           | 1.64        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.33e+03    |
# |    ep_rew_mean          | 264         |
# | time/                   |             |
# |    fps                  | 725         |
# |    iterations           | 3           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.017363805 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.38       |
# |    explained_variance   | 0.39        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.328       |
# |    n_updates            | 1250        |
# |    policy_gradient_loss | -0.0037     |
# |    std                  | 0.445       |
# |    value_loss           | 3.81        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.33e+03    |
# |    ep_rew_mean          | 268         |
# | time/                   |             |
# |    fps                  | 677         |
# |    iterations           | 4           |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.018088195 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.36       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.4         |
# |    n_updates            | 1260        |
# |    policy_gradient_loss | -0.00344    |
# |    std                  | 0.441       |
# |    value_loss           | 2.65        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.28e+03    |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 647         |
# |    iterations           | 5           |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.017690051 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.34       |
# |    explained_variance   | 0.567       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.532       |
# |    n_updates            | 1270        |
# |    policy_gradient_loss | -0.00123    |
# |    std                  | 0.44        |
# |    value_loss           | 5.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.29e+03    |
# |    ep_rew_mean          | 260         |
# | time/                   |             |
# |    fps                  | 638         |
# |    iterations           | 6           |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.016932014 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.31       |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.472       |
# |    n_updates            | 1280        |
# |    policy_gradient_loss | -0.00355    |
# |    std                  | 0.436       |
# |    value_loss           | 2.17        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.26e+03   |
# |    ep_rew_mean          | 248        |
# | time/                   |            |
# |    fps                  | 631        |
# |    iterations           | 7          |
# |    time_elapsed         | 90         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.01585215 |
# |    clip_fraction        | 0.206      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.29      |
# |    explained_variance   | 0.443      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.503      |
# |    n_updates            | 1290       |
# |    policy_gradient_loss | -0.00418   |
# |    std                  | 0.434      |
# |    value_loss           | 4.9        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.24e+03  |
# |    ep_rew_mean          | 244       |
# | time/                   |           |
# |    fps                  | 619       |
# |    iterations           | 8         |
# |    time_elapsed         | 105       |
# |    total_timesteps      | 65536     |
# | train/                  |           |
# |    approx_kl            | 0.0176685 |
# |    clip_fraction        | 0.227     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.3      |
# |    explained_variance   | 0.936     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 7.15      |
# |    n_updates            | 1300      |
# |    policy_gradient_loss | -0.00196  |
# |    std                  | 0.437     |
# |    value_loss           | 7.35      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.21e+03    |
# |    ep_rew_mean          | 234         |
# | time/                   |             |
# |    fps                  | 616         |
# |    iterations           | 9           |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.016432207 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.31       |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.608       |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | -0.000932   |
# |    std                  | 0.438       |
# |    value_loss           | 11          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.22e+03    |
# |    ep_rew_mean          | 237         |
# | time/                   |             |
# |    fps                  | 619         |
# |    iterations           | 10          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.026279379 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.3        |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.63        |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | -0.000145   |
# |    std                  | 0.436       |
# |    value_loss           | 7.78        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.22e+03    |
# |    ep_rew_mean          | 240         |
# | time/                   |             |
# |    fps                  | 619         |
# |    iterations           | 11          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.023445396 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 0.791       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.09        |
# |    n_updates            | 1330        |
# |    policy_gradient_loss | -0.00162    |
# |    std                  | 0.434       |
# |    value_loss           | 10.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.22e+03    |
# |    ep_rew_mean          | 237         |
# | time/                   |             |
# |    fps                  | 616         |
# |    iterations           | 12          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.019292373 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.27       |
# |    explained_variance   | 0.433       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.251       |
# |    n_updates            | 1340        |
# |    policy_gradient_loss | -0.000926   |
# |    std                  | 0.432       |
# |    value_loss           | 2.49        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.21e+03    |
# |    ep_rew_mean          | 235         |
# | time/                   |             |
# |    fps                  | 617         |
# |    iterations           | 13          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.018633526 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.24       |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.181       |
# |    n_updates            | 1350        |
# |    policy_gradient_loss | -0.00375    |
# |    std                  | 0.43        |
# |    value_loss           | 8.54        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.21e+03    |
# |    ep_rew_mean          | 232         |
# | time/                   |             |
# |    fps                  | 616         |
# |    iterations           | 14          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.019988833 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.23       |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.8         |
# |    n_updates            | 1360        |
# |    policy_gradient_loss | -0.00122    |
# |    std                  | 0.428       |
# |    value_loss           | 13.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.21e+03    |
# |    ep_rew_mean          | 235         |
# | time/                   |             |
# |    fps                  | 617         |
# |    iterations           | 15          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.021725722 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.21       |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.822       |
# |    n_updates            | 1370        |
# |    policy_gradient_loss | -0.00231    |
# |    std                  | 0.425       |
# |    value_loss           | 10.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.19e+03    |
# |    ep_rew_mean          | 229         |
# | time/                   |             |
# |    fps                  | 619         |
# |    iterations           | 16          |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.021017013 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.243       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.325       |
# |    n_updates            | 1380        |
# |    policy_gradient_loss | -0.00322    |
# |    std                  | 0.42        |
# |    value_loss           | 4.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.18e+03    |
# |    ep_rew_mean          | 231         |
# | time/                   |             |
# |    fps                  | 619         |
# |    iterations           | 17          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.020881303 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.871       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.83        |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | -0.00121    |
# |    std                  | 0.417       |
# |    value_loss           | 10.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.13e+03   |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 618        |
# |    iterations           | 18         |
# |    time_elapsed         | 238        |
# |    total_timesteps      | 147456     |
# | train/                  |            |
# |    approx_kl            | 0.01895364 |
# |    clip_fraction        | 0.246      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.09      |
# |    explained_variance   | 0.391      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.56       |
# |    n_updates            | 1400       |
# |    policy_gradient_loss | -0.00146   |
# |    std                  | 0.412      |
# |    value_loss           | 3.42       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.14e+03     |
# |    ep_rew_mean          | 220          |
# | time/                   |              |
# |    fps                  | 616          |
# |    iterations           | 19           |
# |    time_elapsed         | 252          |
# |    total_timesteps      | 155648       |
# | train/                  |              |
# |    approx_kl            | 0.0153583195 |
# |    clip_fraction        | 0.171        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.07        |
# |    explained_variance   | 0.915        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.81         |
# |    n_updates            | 1410         |
# |    policy_gradient_loss | -0.00392     |
# |    std                  | 0.411        |
# |    value_loss           | 15.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.14e+03    |
# |    ep_rew_mean          | 220         |
# | time/                   |             |
# |    fps                  | 616         |
# |    iterations           | 20          |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.019301973 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.06       |
# |    explained_variance   | 0.165       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.69        |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | -0.00227    |
# |    std                  | 0.411       |
# |    value_loss           | 3.46        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.12e+03    |
# |    ep_rew_mean          | 217         |
# | time/                   |             |
# |    fps                  | 615         |
# |    iterations           | 21          |
# |    time_elapsed         | 279         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.014846139 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | 0.453       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.819       |
# |    n_updates            | 1430        |
# |    policy_gradient_loss | 0.000575    |
# |    std                  | 0.411       |
# |    value_loss           | 3.27        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.13e+03   |
# |    ep_rew_mean          | 222        |
# | time/                   |            |
# |    fps                  | 612        |
# |    iterations           | 22         |
# |    time_elapsed         | 294        |
# |    total_timesteps      | 180224     |
# | train/                  |            |
# |    approx_kl            | 0.01646835 |
# |    clip_fraction        | 0.199      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.06      |
# |    explained_variance   | 0.903      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 13.8       |
# |    n_updates            | 1440       |
# |    policy_gradient_loss | -0.00216   |
# |    std                  | 0.41       |
# |    value_loss           | 13.9       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.14e+03   |
# |    ep_rew_mean          | 226        |
# | time/                   |            |
# |    fps                  | 609        |
# |    iterations           | 23         |
# |    time_elapsed         | 308        |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.02558307 |
# |    clip_fraction        | 0.243      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.05      |
# |    explained_variance   | 0.789      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.882      |
# |    n_updates            | 1450       |
# |    policy_gradient_loss | -0.00136   |
# |    std                  | 0.409      |
# |    value_loss           | 12.3       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.13e+03   |
# |    ep_rew_mean          | 227        |
# | time/                   |            |
# |    fps                  | 609        |
# |    iterations           | 24         |
# |    time_elapsed         | 322        |
# |    total_timesteps      | 196608     |
# | train/                  |            |
# |    approx_kl            | 0.02353952 |
# |    clip_fraction        | 0.279      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.03      |
# |    explained_variance   | 0.879      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.775      |
# |    n_updates            | 1460       |
# |    policy_gradient_loss | -0.00158   |
# |    std                  | 0.406      |
# |    value_loss           | 8.54       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.13e+03    |
# |    ep_rew_mean          | 228         |
# | time/                   |             |
# |    fps                  | 608         |
# |    iterations           | 25          |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.017566305 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0.491       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.74        |
# |    n_updates            | 1470        |
# |    policy_gradient_loss | -0.00123    |
# |    std                  | 0.403       |
# |    value_loss           | 2.95        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.14e+03    |
# |    ep_rew_mean          | 231         |
# | time/                   |             |
# |    fps                  | 608         |
# |    iterations           | 26          |
# |    time_elapsed         | 349         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.019466931 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.01       |
# |    explained_variance   | 0.489       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01        |
# |    n_updates            | 1480        |
# |    policy_gradient_loss | -0.00326    |
# |    std                  | 0.406       |
# |    value_loss           | 3.19        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.13e+03   |
# |    ep_rew_mean          | 231        |
# | time/                   |            |
# |    fps                  | 608        |
# |    iterations           | 27         |
# |    time_elapsed         | 363        |
# |    total_timesteps      | 221184     |
# | train/                  |            |
# |    approx_kl            | 0.01448741 |
# |    clip_fraction        | 0.204      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.01      |
# |    explained_variance   | 0.889      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.746      |
# |    n_updates            | 1490       |
# |    policy_gradient_loss | -0.00138   |
# |    std                  | 0.405      |
# |    value_loss           | 10.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.11e+03    |
# |    ep_rew_mean          | 228         |
# | time/                   |             |
# |    fps                  | 607         |
# |    iterations           | 28          |
# |    time_elapsed         | 377         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.021778077 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 0.884       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.29        |
# |    n_updates            | 1500        |
# |    policy_gradient_loss | -0.00392    |
# |    std                  | 0.403       |
# |    value_loss           | 5.32        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.11e+03    |
# |    ep_rew_mean          | 229         |
# | time/                   |             |
# |    fps                  | 606         |
# |    iterations           | 29          |
# |    time_elapsed         | 391         |
# |    total_timesteps      | 237568      |
# | train/                  |             |
# |    approx_kl            | 0.022027327 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | 0.891       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.67        |
# |    n_updates            | 1510        |
# |    policy_gradient_loss | -0.000364   |
# |    std                  | 0.4         |
# |    value_loss           | 9.13        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.11e+03    |
# |    ep_rew_mean          | 231         |
# | time/                   |             |
# |    fps                  | 604         |
# |    iterations           | 30          |
# |    time_elapsed         | 406         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.025988963 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.22        |
# |    n_updates            | 1520        |
# |    policy_gradient_loss | -0.000852   |
# |    std                  | 0.396       |
# |    value_loss           | 7.98        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.12e+03    |
# |    ep_rew_mean          | 236         |
# | time/                   |             |
# |    fps                  | 601         |
# |    iterations           | 31          |
# |    time_elapsed         | 422         |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.020978129 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | 0.854       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.64        |
# |    n_updates            | 1530        |
# |    policy_gradient_loss | -0.00268    |
# |    std                  | 0.396       |
# |    value_loss           | 9.47        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.14e+03    |
# |    ep_rew_mean          | 245         |
# | time/                   |             |
# |    fps                  | 601         |
# |    iterations           | 32          |
# |    time_elapsed         | 436         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.019568246 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | 0.556       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.33        |
# |    n_updates            | 1540        |
# |    policy_gradient_loss | -0.00398    |
# |    std                  | 0.394       |
# |    value_loss           | 3.9         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.13e+03    |
# |    ep_rew_mean          | 244         |
# | time/                   |             |
# |    fps                  | 600         |
# |    iterations           | 33          |
# |    time_elapsed         | 450         |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.017674882 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.342       |
# |    n_updates            | 1550        |
# |    policy_gradient_loss | -0.00223    |
# |    std                  | 0.393       |
# |    value_loss           | 7.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.13e+03    |
# |    ep_rew_mean          | 243         |
# | time/                   |             |
# |    fps                  | 599         |
# |    iterations           | 34          |
# |    time_elapsed         | 464         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.020492464 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | 0.877       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.2         |
# |    n_updates            | 1560        |
# |    policy_gradient_loss | -0.000711   |
# |    std                  | 0.391       |
# |    value_loss           | 9.72        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.14e+03    |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 598         |
# |    iterations           | 35          |
# |    time_elapsed         | 479         |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.021211132 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.27        |
# |    n_updates            | 1570        |
# |    policy_gradient_loss | -0.000647   |
# |    std                  | 0.392       |
# |    value_loss           | 15.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.13e+03    |
# |    ep_rew_mean          | 254         |
# | time/                   |             |
# |    fps                  | 597         |
# |    iterations           | 36          |
# |    time_elapsed         | 493         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.016976051 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | 0.416       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.241       |
# |    n_updates            | 1580        |
# |    policy_gradient_loss | 1.97e-05    |
# |    std                  | 0.389       |
# |    value_loss           | 4.66        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.12e+03    |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 597         |
# |    iterations           | 37          |
# |    time_elapsed         | 507         |
# |    total_timesteps      | 303104      |
# | train/                  |             |
# |    approx_kl            | 0.017528366 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | 0.579       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.8         |
# |    n_updates            | 1590        |
# |    policy_gradient_loss | -0.00357    |
# |    std                  | 0.386       |
# |    value_loss           | 4.03        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.11e+03    |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 38          |
# |    time_elapsed         | 522         |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.021142457 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | 0.891       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.07        |
# |    n_updates            | 1600        |
# |    policy_gradient_loss | -0.000888   |
# |    std                  | 0.387       |
# |    value_loss           | 9.58        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.09e+03    |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 39          |
# |    time_elapsed         | 536         |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.021022981 |
# |    clip_fraction        | 0.271       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | 0.573       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.27        |
# |    n_updates            | 1610        |
# |    policy_gradient_loss | -0.00422    |
# |    std                  | 0.386       |
# |    value_loss           | 4.41        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.09e+03    |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 40          |
# |    time_elapsed         | 551         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.017151913 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.853       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.38        |
# |    n_updates            | 1620        |
# |    policy_gradient_loss | -0.00287    |
# |    std                  | 0.385       |
# |    value_loss           | 8.97        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.09e+03   |
# |    ep_rew_mean          | 258        |
# | time/                   |            |
# |    fps                  | 593        |
# |    iterations           | 41         |
# |    time_elapsed         | 566        |
# |    total_timesteps      | 335872     |
# | train/                  |            |
# |    approx_kl            | 0.02019712 |
# |    clip_fraction        | 0.268      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.82      |
# |    explained_variance   | 0.517      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.59       |
# |    n_updates            | 1630       |
# |    policy_gradient_loss | -0.00357   |
# |    std                  | 0.385      |
# |    value_loss           | 5.04       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.09e+03   |
# |    ep_rew_mean          | 261        |
# | time/                   |            |
# |    fps                  | 592        |
# |    iterations           | 42         |
# |    time_elapsed         | 580        |
# |    total_timesteps      | 344064     |
# | train/                  |            |
# |    approx_kl            | 0.02438767 |
# |    clip_fraction        | 0.233      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.8       |
# |    explained_variance   | 0.846      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.52       |
# |    n_updates            | 1640       |
# |    policy_gradient_loss | -0.00254   |
# |    std                  | 0.385      |
# |    value_loss           | 7.65       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.08e+03    |
# |    ep_rew_mean          | 263         |
# | time/                   |             |
# |    fps                  | 590         |
# |    iterations           | 43          |
# |    time_elapsed         | 596         |
# |    total_timesteps      | 352256      |
# | train/                  |             |
# |    approx_kl            | 0.016648173 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.842       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.25        |
# |    n_updates            | 1650        |
# |    policy_gradient_loss | -0.00233    |
# |    std                  | 0.385       |
# |    value_loss           | 9.86        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.07e+03    |
# |    ep_rew_mean          | 263         |
# | time/                   |             |
# |    fps                  | 590         |
# |    iterations           | 44          |
# |    time_elapsed         | 610         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.024020752 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.877       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.95        |
# |    n_updates            | 1660        |
# |    policy_gradient_loss | -0.0022     |
# |    std                  | 0.387       |
# |    value_loss           | 10.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.07e+03    |
# |    ep_rew_mean          | 265         |
# | time/                   |             |
# |    fps                  | 589         |
# |    iterations           | 45          |
# |    time_elapsed         | 625         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.023411952 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.445       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.83        |
# |    n_updates            | 1670        |
# |    policy_gradient_loss | 3.76e-05    |
# |    std                  | 0.385       |
# |    value_loss           | 10.5        |
# -----------------------------------------

# %%
ppo_path = os.path.join('Training', 'Saved Models', 'PPO_Walker_model_5M')

# %%
model.save(ppo_path)
